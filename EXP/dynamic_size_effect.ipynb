# %%
from EXP_package.read_data import *
from EXP_package.entropy import *
from EXP_package.functions import *
import os

platform='voat'
df = read_data(platform)
df=process_posts(df)
entropy_by_class = calculate_entropy_by_class(df, max_size=1000, step=20)
plot_entropy(entropy_by_class, platform)
# Out:
# Processing posts: 100%|██████████| 3506699/3506699 [02:07<00:00, 27426.80it/s]
# /home/jacoponudo/Documents/Size_effects/EXP/EXP_package/entropy.py:42: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   entropy_by_class = df_filtered.groupby('size_grouped').apply(calculate_len_entropy)

# %%
from EXP_package.read_data import *
from EXP_package.entropy import *
from EXP_package.functions import *
import os
platforms = ['facebook', 'reddit', 'gab', 'voat','twitter','usenet']
save_folder = '/home/jacoponudo/Documents/Size_effects/PLT/5_dynamic_entropy'
max_size = 5000
step = 30

# Ensure the save folder exists
os.makedirs(save_folder, exist_ok=True)

for platform in platforms:
    df = read_data(platform)
    df = process_posts(df)
    entropy_by_class = calculate_entropy_by_class(df, max_size=max_size, step=step)
    
    # Save the plot
    plot_entropy(entropy_by_class, platform)
    save_path = os.path.join(save_folder, f'{platform}_dynamic_entropy.png')
    
    # Assuming plot_entropy function saves the plot, alternatively you might need to use plt.savefig()
    plt.savefig(save_path)
    plt.close()
# Out:
# /home/jacoponudo/Documents/Size_effects/EXP/EXP_package/read_data.py:33: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   posts_dict = posts.set_index('post_id').T.to_dict()

# %%
from EXP_package.read_data import *
from EXP_package.entropy import *
from EXP_package.functions import *
import os
platforms = ['twitter','usenet']
save_folder = '/home/jacoponudo/Documents/Size_effects/PLT/5_dynamic_entropy'
max_size = 1000
step = 20

# Ensure the save folder exists
os.makedirs(save_folder, exist_ok=True)

for platform in platforms:
    df = read_data(platform)
    df = process_posts(df)
    entropy_by_class = calculate_entropy_by_class(df, max_size=max_size, step=step)
    
    # Save the plot
    plot_entropy(entropy_by_class, platform)
    save_path = os.path.join(save_folder, f'{platform}_dynamic_entropy.png')
    
    # Assuming plot_entropy function saves the plot, alternatively you might need to use plt.savefig()
    plt.savefig(save_path)
    plt.close()
# Out:
# /home/jacoponudo/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# Processing posts:   1%|          | 667929/68634654 [01:13<2:04:33, 9093.80it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_94244/3966817580.py in ?()
#      11 os.makedirs(save_folder, exist_ok=True)
#      12
#      13 for platform in platforms:
#      14     df = read_data(platform)
# ---> 15     df = process_posts(df)
#      16     entropy_by_class = calculate_entropy_by_class(df, max_size=max_size, step=step)
#      17
#      18     # Save the plot
#
# ...
