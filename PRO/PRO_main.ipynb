# %% [markdown]
# ### Usenet

# %%
import runpy


runpy.run_path('/home/jacoponudo/Documents/Size_effects/PRO/PRO_usenet.py')

# %% [markdown]
# ### Twitter

# %%
import runpy


runpy.run_path('/home/jacoponudo/Documents/Size_effects/PRO/PRO_twitter.py')

# %% [markdown]
# ### Facebook

# %%
import runpy


runpy.run_path('/home/jacoponudo/Documents/Size_effects/PRO/PRO_facebook.py')
# Out:
# /home/jacoponudo/Documents/Size_effects/PRO/PRO_facebook.py:19: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   posts = pd.read_csv('/home/jacoponudo/Documents/Size_effects/DATA/sample_posts.csv', usecols=[ 'page_id', 'post_id'], encoding='ISO-8859-1')
# /home/jacoponudo/Documents/Size_effects/PRO/PRO_facebook.py:27: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   else:
# Number of posts: 659614
# Number of unique users: 7032208
# Total number of rows: 36025483
# {'__name__': '<run_path>',
#  '__doc__': None,
#  '__package__': '',
#  '__loader__': None,
#  '__spec__': None,
#  '__file__': '/home/jacoponudo/Documents/Size_effects/PRO/PRO_facebook.py',
#  '__cached__': None,
#  '__builtins__': {'__name__': 'builtins',
#   '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#   '__package__': '',
# ...

# %%
# Out:
# /tmp/ipykernel_77339/3605562994.py:20: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   posts_dict = posts.set_index('post_id').T.to_dict()
# Number of posts: 3
# Number of unique users: 9
# Total number of rows: 10

# %%
# Out:
# Number of posts: 325451
# Number of unique users: 13620442
# Total number of rows: 68634654

# %%
final_dataset
